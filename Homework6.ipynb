# %% [markdown]
# # Thinh Nguyen
# # Dr Olenick
# # Homework 6
# # 11/4/2022

# %%
#projectile motion.py
#baseball pitch

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

k_l = 4.0E-4
omega = 2500/60*2*np.pi #spin speed in rev/min
#init param
g = 9.81
v0 = 45 #m/s 
x = 0
y = 0 #init position
t = 0 #time
h = 0.001 #time step (dt)
theta = 3 #angle of projection (degree)
z = 1.8
phi = 135*np.pi/180 #45 degree
#create array to store data, new value will be appended 
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)
zc = np.zeros(0)

#drag coefficient--------------------------------
def k_D(v):
    delta = 5.0
    vd = 35.0
    return 0.0039 + 0.0058/(1/np.exp((v-vd)/delta))
#------------------------------------------------

#define acceleration func------------------------
def ax(vx,vy,vz,v):
    return -k_D(v)*v*vx + k_l*(omega*np.sin(phi)*vz - omega*np.cos(phi)*vy)
def ay(vx, vy, v):
    return -k_D(v)*v*vy + k_l*omega*vx*np.cos(phi)
def az(vx,vz,v):
    return -k_D(v)*v*vz - k_l*omega*vx*np.sin(phi) - g
#------------------------------------------------

#define Heun's method----------------------------
def heun_vx(vx,vy,vz,v):
    heun_end = vx + ax(vx,vy,vz,v)*h
    vx = vx + (ax(vx,vy,vz,v)+ ax(heun_end,vy,vz,v))/2*h
    return vx
def heun_vy(vx,vy,v):
    heun_end = vy + az(vx,vy,v)*h
    vy = vy + (ay(vx,vy,v)+ ay(vx,heun_end,v))/2*h
    return vy
def heun_vz(vx,vz,v):
    heun_end = vz + az(vx,vz,v)*h
    vz = vz + (az(vx,vz,v)+ az(vx,heun_end,v))/2*h
    return vz
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y
def heun_x(x,vx):
    x = x + vx*h
    return x
def heun_z(z,vz):
    z = z + vz*h
    return z

#------------------------------------------------
vx = v0*np.cos(theta*np.pi/180)
vz = v0*np.sin(theta*np.pi/180)
v = v0
vy = 0

#iterate over time-------------------------------
#while y >= 0:
while x <= 18.44:
    xc = np.append(xc,x)
    yc = np.append(yc,y)
    zc = np.append(zc,z)
    tc = np.append(tc,t)
    
    vx = heun_vx(vx,vy,vz,v)
    x = heun_x(x, vx)
    
    vy = heun_vy(vx,vy,v)
    y = heun_y(y,vy)
    
    vz = heun_vz(vx,vz,v)
    z = heun_z(z, vz)
    
    v = np.sqrt(vx**2 + vy**2 + vz**2) #update value of velocity  
    
    t = t + h
 
#plot in 3D-------------------------------------
print("Graph of a screwball (phi = 135 degrees)")
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.plot(xc,yc,zs = zc, zdir='z')
# Out:
# Graph of a screwball (phi = 135 degrees)
# C:\Users\Thinh\AppData\Local\Temp\ipykernel_1176\3357951202.py:98: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
#projectile motion.py
#baseball pitch

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

k_l = 4.0E-4
omega = 2500/60*2*np.pi #spin speed in rev/min
#init param
g = 9.81
v0 = 45 #m/s 
x = 0
y = 0 #init position
t = 0 #time
h = 0.001 #time step (dt)
theta = 3 #angle of projection (degree)
z = 1.8
phi = 225*np.pi/180 #45 degree
#create array to store data, new value will be appended 
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)
zc = np.zeros(0)

#drag coefficient--------------------------------
def k_D(v):
    delta = 5.0
    vd = 35.0
    return 0.0039 + 0.0058/(1/np.exp((v-vd)/delta))
#------------------------------------------------

#define acceleration func------------------------
def ax(vx,vy,vz,v):
    return -k_D(v)*v*vx + k_l*(omega*np.sin(phi)*vz - omega*np.cos(phi)*vy)
def ay(vx, vy, v):
    return -k_D(v)*v*vy + k_l*omega*vx*np.cos(phi)
def az(vx,vz,v):
    return -k_D(v)*v*vz - k_l*omega*vx*np.sin(phi) - g
#------------------------------------------------

#define Heun's method----------------------------
def heun_vx(vx,vy,vz,v):
    heun_end = vx + ax(vx,vy,vz,v)*h
    vx = vx + (ax(vx,vy,vz,v)+ ax(heun_end,vy,vz,v))/2*h
    return vx
def heun_vy(vx,vy,v):
    heun_end = vy + az(vx,vy,v)*h
    vy = vy + (ay(vx,vy,v)+ ay(vx,heun_end,v))/2*h
    return vy
def heun_vz(vx,vz,v):
    heun_end = vz + az(vx,vz,v)*h
    vz = vz + (az(vx,vz,v)+ az(vx,heun_end,v))/2*h
    return vz
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y
def heun_x(x,vx):
    x = x + vx*h
    return x
def heun_z(z,vz):
    z = z + vz*h
    return z

#------------------------------------------------
vx = v0*np.cos(theta*np.pi/180)
vz = v0*np.sin(theta*np.pi/180)
v = v0
vy = 0

#iterate over time-------------------------------
#while y >= 0:
while x <= 18.44:
    xc = np.append(xc,x)
    yc = np.append(yc,y)
    zc = np.append(zc,z)
    tc = np.append(tc,t)
    
    vx = heun_vx(vx,vy,vz,v)
    x = heun_x(x, vx)
    
    vy = heun_vy(vx,vy,v)
    y = heun_y(y,vy)
    
    vz = heun_vz(vx,vz,v)
    z = heun_z(z, vz)
    
    v = np.sqrt(vx**2 + vy**2 + vz**2) #update value of velocity  
    
    t = t + h
 
#plot in 3D-------------------------------------
print("Graph of a fastball (phi = 225 degrees)")
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.plot(xc,yc,zs = zc, zdir='z')
# Out:
# Graph of a fastball (phi = 225 degrees)
# C:\Users\Thinh\AppData\Local\Temp\ipykernel_1176\487762374.py:98: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
#projectile motion.py
#baseball pitch

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

k_l = 4.0E-4
omega = 2500/60*2*np.pi #spin speed in rev/min
#init param
g = 9.81
v0 = 45 #m/s 
x = 0
y = 0 #init position
t = 0 #time
h = 0.001 #time step (dt)
theta = 3 #angle of projection (degree)
z = 1.8
phi = 0*np.pi/180 #45 degree
#create array to store data, new value will be appended 
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)
zc = np.zeros(0)

#drag coefficient--------------------------------
def k_D(v):
    delta = 5.0
    vd = 35.0
    return 0.0039 + 0.0058/(1/np.exp((v-vd)/delta))
#------------------------------------------------

#define acceleration func------------------------
def ax(vx,vy,vz,v):
    return -k_D(v)*v*vx + k_l*(omega*np.sin(phi)*vz - omega*np.cos(phi)*vy)
def ay(vx, vy, v):
    return -k_D(v)*v*vy + k_l*omega*vx*np.cos(phi)
def az(vx,vz,v):
    return -k_D(v)*v*vz - k_l*omega*vx*np.sin(phi) - g
#------------------------------------------------

#define Heun's method----------------------------
def heun_vx(vx,vy,vz,v):
    heun_end = vx + ax(vx,vy,vz,v)*h
    vx = vx + (ax(vx,vy,vz,v)+ ax(heun_end,vy,vz,v))/2*h
    return vx
def heun_vy(vx,vy,v):
    heun_end = vy + az(vx,vy,v)*h
    vy = vy + (ay(vx,vy,v)+ ay(vx,heun_end,v))/2*h
    return vy
def heun_vz(vx,vz,v):
    heun_end = vz + az(vx,vz,v)*h
    vz = vz + (az(vx,vz,v)+ az(vx,heun_end,v))/2*h
    return vz
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y
def heun_x(x,vx):
    x = x + vx*h
    return x
def heun_z(z,vz):
    z = z + vz*h
    return z

#------------------------------------------------
vx = v0*np.cos(theta*np.pi/180)
vz = v0*np.sin(theta*np.pi/180)
v = v0
vy = 0

#iterate over time-------------------------------
#while y >= 0:
while x <= 18.44:
    xc = np.append(xc,x)
    yc = np.append(yc,y)
    zc = np.append(zc,z)
    tc = np.append(tc,t)
    
    vx = heun_vx(vx,vy,vz,v)
    x = heun_x(x, vx)
    
    vy = heun_vy(vx,vy,v)
    y = heun_y(y,vy)
    
    vz = heun_vz(vx,vz,v)
    z = heun_z(z, vz)
    
    v = np.sqrt(vx**2 + vy**2 + vz**2) #update value of velocity  
    
    t = t + h
 
#plot in 3D-------------------------------------
print("Graph of a slider (phi = 0 degrees)")
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.plot(xc,yc,zs = zc, zdir='z')
# Out:
# Graph of a slider (phi = 0 degrees)
# C:\Users\14694\AppData\Local\Temp\ipykernel_14576\2553498021.py:98: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
#projectile motion.py
#baseball pitch

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

k_l = 4.0E-4
omega = 2500/60*2*np.pi #spin speed in rev/min
#init param
g = 9.81
v0 = 45 #m/s 
x = 0
y = 0 #init position
t = 0 #time
h = 0.001 #time step (dt)
theta = 3 #angle of projection (degree)
z = 1.8
phi = 45*np.pi/180 #45 degree
#create array to store data, new value will be appended 
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)
zc = np.zeros(0)

#drag coefficient--------------------------------
def k_D(v):
    delta = 5.0
    vd = 35.0
    return 0.0039 + 0.0058/(1/np.exp((v-vd)/delta))
#------------------------------------------------

#define acceleration func------------------------
def ax(vx,vy,vz,v):
    return -k_D(v)*v*vx + k_l*(omega*np.sin(phi)*vz - omega*np.cos(phi)*vy)
def ay(vx, vy, v):
    return -k_D(v)*v*vy + k_l*omega*vx*np.cos(phi)
def az(vx,vz,v):
    return -k_D(v)*v*vz - k_l*omega*vx*np.sin(phi) - g
#------------------------------------------------

#define Heun's method----------------------------
def heun_vx(vx,vy,vz,v):
    heun_end = vx + ax(vx,vy,vz,v)*h
    vx = vx + (ax(vx,vy,vz,v)+ ax(heun_end,vy,vz,v))/2*h
    return vx
def heun_vy(vx,vy,v):
    heun_end = vy + az(vx,vy,v)*h
    vy = vy + (ay(vx,vy,v)+ ay(vx,heun_end,v))/2*h
    return vy
def heun_vz(vx,vz,v):
    heun_end = vz + az(vx,vz,v)*h
    vz = vz + (az(vx,vz,v)+ az(vx,heun_end,v))/2*h
    return vz
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y
def heun_x(x,vx):
    x = x + vx*h
    return x
def heun_z(z,vz):
    z = z + vz*h
    return z

#------------------------------------------------
vx = v0*np.cos(theta*np.pi/180)
vz = v0*np.sin(theta*np.pi/180)
v = v0
vy = 0

#iterate over time-------------------------------
#while y >= 0:
while x <= 18.44:
    xc = np.append(xc,x)
    yc = np.append(yc,y)
    zc = np.append(zc,z)
    tc = np.append(tc,t)
    
    vx = heun_vx(vx,vy,vz,v)
    x = heun_x(x, vx)
    
    vy = heun_vy(vx,vy,v)
    y = heun_y(y,vy)
    
    vz = heun_vz(vx,vz,v)
    z = heun_z(z, vz)
    
    v = np.sqrt(vx**2 + vy**2 + vz**2) #update value of velocity  
    
    t = t + h
 
#plot in 3D-------------------------------------
print("Graph of a curveball (phi = 45 degrees)")
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.plot(xc,yc,zs = zc, zdir='z')
# Out:
# Graph of a curveball (phi = 45 degrees)
# C:\Users\Thinh\AppData\Local\Temp\ipykernel_8976\3632905952.py:98: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# Type of Pitch: <br>
#     Fastball: 0.05ft(y) 2.04ft(z) <br>
#     Slider: 0.48ft(y) 1.81ft(z) <br>
#     Curveball: 0.33ft(y) 1.57ft(z) <br>
#     Screwball: 0.3ft(y) 1.91ft(z) <br>

# %%
#freefall

import numpy as np
import matplotlib.pyplot as plt

#init param
g = 9.81
v0 = 0 #m/s
vt = 10.0 #m/s ping pong ball terminal speed 
y = 57 #init position in m
t = 0 #time
h = 0.01 #time step (dt)
#create array to store data, new value will be appended
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)

#define acceleration func------------------------
#wifout air resistence 
def ay_na():
    return -g
#------------------------------------------------

#define Heun's method----------------------------
#wifout air resistance
def heun_vy_na(vy,v):
    heun_end = vy + ay_na()*h
    vy = vy + (ay_na()+ ay_na())/2*h
    return vy
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y

#------------------------------------------------

vy = v0
v = v0
#iterate over time-------------------------------
while y >= 0:
    yc = np.append(yc,y)
    tc = np.append(tc,t)
   
   
    vy = heun_vy_na(vy,v)
    y = heun_y(y,vy)
   
    v = np.sqrt(vy**2) #update value of velocity  
    t = t + h
 

plt.xlabel("Time(s)")
plt.ylabel("Vertical Position(m)")
plt.plot(tc,yc,'c')
plt.show()
print("time for the ball to reach the ground without air resistance:{0:4.2f}".format(tc[np.argmin(yc)]))


print("the speed of the ball @ any instance without air resistence: " + str(yc[np.argmax(yc)] / tc[np.argmax(tc)]))
# Out:
# time for the ball to reach the ground without air resistance:3.40
# the speed of the ball @ any instance without air resistence: 16.76470588235308

# %%
#freefall

import numpy as np
import matplotlib.pyplot as plt

#init param
g = 9.81
v0 = 0 #m/s
vt = 10.0 #m/s ping pong ball terminal speed 
y = 57 #init position in m
t = 0 #time
h = 0.01 #time step (dt)
#create array to store data, new value will be appended
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)

#define acceleration func------------------------
#wif air resistence 
def ay(vy, v):
    return -g*(1+ vy*v/vt**2)
#------------------------------------------------

#define Heun's method----------------------------
def heun_vy(vy,v):
    heun_end = vy + ay(vy,v)*h
    vy = vy + (ay(vy,v)+ ay(heun_end,v))/2*h
    return vy
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y

#------------------------------------------------
vy = v0
v = v0

#iterate over time-------------------------------
while y >= 0:
    yc = np.append(yc,y)
    tc = np.append(tc,t)
   
   
    vy = heun_vy(vy,v)
    y = heun_y(y,vy)
   
    v = np.sqrt(vy**2) #update value of velocity  
    t = t + h
 

plt.xlabel("Time(s)")
plt.ylabel("Vertical Position(m)")
plt.plot(tc,yc,'c')
plt.show()
print("time for the ball to reach the ground with air resistance:{0:4.2f}".format(tc[np.argmin(yc)]))

print("the speed of the ball @ any instance with air resistence: " + str(yc[np.argmax(yc)] / tc[np.argmax(tc)]))
# Out:
# time for the ball to reach the ground with air resistance:6.40
# the speed of the ball @ any instance with air resistence: 8.906250000000128

# %%
import numpy as np
import matplotlib.pyplot as plt
#define function to calculate motion of football
g=9.81
vt=45.0
x,y,t=0,0,0
def euler(vx, vy):
# we have to restart x,y,t to 0 for each value of theta
    x, y, t = 0,0,0
    g, vt = 9.81, 45.0 #gravity, terminal velocity
    dt = 0.005 #time step
    while y >=0:
        v = np.sqrt(vx**2 + vy**2)
        ay = -g*(1 + vy*v/vt**2)
        ax = -g*vx*v/vt**2*dt
        vx = vx + ax*dt
        vy = vy + ay*dt
        x = x + vx*dt
        y = y + vy*dt
        t = t + dt
    return x
Angle = np.zeros(0)
Range = np.zeros(0)
#Loop to run it multiple times
for theta in np.arange(30.0, 60.0, 0.50):
    v = 27.0
    vx = v*np.cos(theta*np.pi/180.0)
    vy = v*np.sin(theta*np.pi/180.0)
    x = euler(vx, vy)
    Range = np.append(Range,x) #append the new range
    Angle = np.append(Angle, theta) #append the angle to our array
print("The maximum range of {:4.2f} m".format( Range[np.argmax(Range)]))
print("occurs at angle = {:4.2f} degrees".format(Angle[np.argmax(Range)]))
print('No air resistance range = {:4.2f} m'.format( v**2/g))
plt.xlabel("Theta (degrees)")
plt.ylabel("Range (m)")
plt.title("Angle vs. Range")
plt.plot(Angle, Range, 'b-')
plt.show()
# Out:
# The maximum range of 69.27 m
# occurs at angle = 44.00 degrees
# No air resistance range = 74.31 m

# %% [markdown]
# He should throw the ball @ 44 degrees for the biggest range. <br>
# Yes, the result does agree with this observation.

# %%
#biking.py

import matplotlib.pyplot as plt
import numpy as np

#parameters--------------------
g = 9.8
k_D = 0.5
v = 4.0 #init spd
P = 500 #watts
m = 70 #mass in kilos

x = 0
t = 0
h = 0.01
A = 0.33
rho = 1.2
#-------------------------------

#arrays of t and v
vc = np.zeros(0)
tc = np.zeros(0) 


#define acceleration------------
#not riding uphill nor downhill, so no factor*g*np.sin(6*np.pi/180)
def ax(v):
    return (-0.5*k_D*np.abs(v)*v*rho*A) + (P/(m*v))
#-------------------------------

#define heun's method-----------
def heun_v(v):
    heun_end = v + ax(v)*h
    v = v + (ax(v)+ ax(heun_end))/2*h
    return v
def heun_x(x,v):
    x = x + v*h
    return x
#-------------------------------

#iterate over time--------------
while t <= 200:
    v = heun_v(v)
    x = heun_x(x, v)
    vc = np.append(vc,v)
    tc = np.append(tc,t)
    t = t + h
#find v and x-------------------


plt.xlabel('t')
plt.ylabel('speed')
plt.plot(tc, vc, 'r')

# %% [markdown]
# The result we got isn't close to the average result of 15m/s

# %%
#projectile motion.py
#baseball pitch

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

k_l = 1.72E-3
omega = 3600/60*2*np.pi #spin speed in rev/min
#init param
g = 9.81
v0 = 134 #m/s 
x = 0
y = 0 #init position
t = 0 #time
h = 0.001 #time step (dt)
theta = 8 #angle of projection (degree)
z = 1.8
phi = -np.pi/2 #-np.pi/2 for homeworkk 6 last question
#create array to store data, new value will be appended 
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)
zc = np.zeros(0)

#drag coefficient--------------------------------
#C_D = 0.3, rho = 1.2754, A = 0.02135, m = 0.04593
# k_D = C_D*rho*A / (2*m)
def k_D(v):
    return (0.3*1.2754*0.02135)/(2*0.04593) 
#------------------------------------------------

#define acceleration func------------------------
def ax(vx,vy,vz,v):
    return -k_D(v)*v*vx + k_l*(omega*np.sin(phi)*vz - omega*np.cos(phi)*vy)
def ay(vx, vy, v):
    return -k_D(v)*v*vy + k_l*omega*vx*np.cos(phi)
def az(vx,vz,v):
    return -k_D(v)*v*vz - k_l*omega*vx*np.sin(phi) - g
#------------------------------------------------

#define Heun's method----------------------------
def heun_vx(vx,vy,vz,v):
    heun_end = vx + ax(vx,vy,vz,v)*h
    vx = vx + (ax(vx,vy,vz,v)+ ax(heun_end,vy,vz,v))/2*h
    return vx
def heun_vy(vx,vy,v):
    heun_end = vy + az(vx,vy,v)*h
    vy = vy + (ay(vx,vy,v)+ ay(vx,heun_end,v))/2*h
    return vy
def heun_vz(vx,vz,v):
    heun_end = vz + az(vx,vz,v)*h
    vz = vz + (az(vx,vz,v)+ az(vx,heun_end,v))/2*h
    return vz
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y
def heun_x(x,vx):
    x = x + vx*h
    return x
def heun_z(z,vz):
    z = z + vz*h
    return z

#------------------------------------------------
vx = v0*np.cos(theta*np.pi/180)
vz = v0*np.sin(theta*np.pi/180)
v = v0
vy = 0

#iterate over time-------------------------------
#while y >= 0:
while z>=0:
    xc = np.append(xc,x)
    yc = np.append(yc,y)
    zc = np.append(zc,z)
    tc = np.append(tc,t)
    
    vx = heun_vx(vx,vy,vz,v)
    x = heun_x(x, vx)
    
    vy = heun_vy(vx,vy,v)
    y = heun_y(y,vy)
    
    vz = heun_vz(vx,vz,v)
    z = heun_z(z, vz)
    
    v = np.sqrt(vx**2 + vy**2 + vz**2) #update value of velocity  
    
    t = t + h
 
#plot in 3D-------------------------------------
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.plot(xc,yc,zs = zc, zdir='z')
print(str(xc[np.argmax(xc)]))
# Out:
# 41.327288787314835
# C:\Users\Thinh\AppData\Local\Temp\ipykernel_8976\850309469.py:97: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# Max range = 41.327288787314835m at theta = 8 degrees, 3600 rpm and v_0 = 134m/s

# %%
#projectile motion.py
#baseball pitch

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

k_l = 1.72E-3
omega = 7200/60*2*np.pi #spin speed in rev/min
#init param
g = 9.81
v0 = 105 #m/s 
x = 0
y = 0 #init position
t = 0 #time
h = 0.001 #time step (dt)
theta = 23 #angle of projection (degree)
z = 1.8
phi = -np.pi/2 #-np.pi/2 for homeworkk 6 last question
#create array to store data, new value will be appended 
tc = np.zeros(0)
xc = np.zeros(0)
yc = np.zeros(0)
zc = np.zeros(0)

#drag coefficient--------------------------------
#C_D = 0.3, rho = 1.2754, A = 0.02135, m = 0.04593
# k_D = C_D*rho*A / (2*m)
def k_D(v):
    return (0.3*1.2754*0.02135)/(2*0.04593) 
#------------------------------------------------

#define acceleration func------------------------
def ax(vx,vy,vz,v):
    return -k_D(v)*v*vx + k_l*(omega*np.sin(phi)*vz - omega*np.cos(phi)*vy)
def ay(vx, vy, v):
    return -k_D(v)*v*vy + k_l*omega*vx*np.cos(phi)
def az(vx,vz,v):
    return -k_D(v)*v*vz - k_l*omega*vx*np.sin(phi) - g
#------------------------------------------------

#define Heun's method----------------------------
def heun_vx(vx,vy,vz,v):
    heun_end = vx + ax(vx,vy,vz,v)*h
    vx = vx + (ax(vx,vy,vz,v)+ ax(heun_end,vy,vz,v))/2*h
    return vx
def heun_vy(vx,vy,v):
    heun_end = vy + az(vx,vy,v)*h
    vy = vy + (ay(vx,vy,v)+ ay(vx,heun_end,v))/2*h
    return vy
def heun_vz(vx,vz,v):
    heun_end = vz + az(vx,vz,v)*h
    vz = vz + (az(vx,vz,v)+ az(vx,heun_end,v))/2*h
    return vz
#------------------------------------------------

#define heun's method for y----------------------
def heun_y(y,vy):
    y = y + vy*h
    return y
def heun_x(x,vx):
    x = x + vx*h
    return x
def heun_z(z,vz):
    z = z + vz*h
    return z

#------------------------------------------------
vx = v0*np.cos(theta*np.pi/180)
vz = v0*np.sin(theta*np.pi/180)
v = v0
vy = 0

#iterate over time-------------------------------
#while y >= 0:
while z>=0:
    xc = np.append(xc,x)
    yc = np.append(yc,y)
    zc = np.append(zc,z)
    tc = np.append(tc,t)
    
    vx = heun_vx(vx,vy,vz,v)
    x = heun_x(x, vx)
    
    vy = heun_vy(vx,vy,v)
    y = heun_y(y,vy)
    
    vz = heun_vz(vx,vz,v)
    z = heun_z(z, vz)
    
    v = np.sqrt(vx**2 + vy**2 + vz**2) #update value of velocity  
    
    t = t + h
 
#plot in 3D-------------------------------------
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.plot(xc,yc,zs = zc, zdir='z')
print(str(xc[np.argmax(xc)]))
# Out:
# 44.00521783590376
# C:\Users\Thinh\AppData\Local\Temp\ipykernel_8976\2689051873.py:97: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# Max range = 44.00521783590376m at theta = 23 degrees, 7200 rpm and v_0 = 105 m/s
